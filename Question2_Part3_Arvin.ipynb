# %% [markdown]
# <h3 align=middle style="line-height:500%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Project Three, Question Two, Part Three
# </font>
# </h3>

# %% [markdown]
# <h3 align=left style="line-height:500%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Part Three:
# </font>
# </h3>
#
# We pretty much processed our data through parts 1&2 and now we have a great view about its columns and their relations, so we will just impor the data saved in the previous notebook and continue our journey.

# %% [markdown]
# <h3 align=left style="line-height:500%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# Preprocessing phase:
# </font>
# </h3>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# %%
train = pd.read_csv(r"C:\Users\ROG\Desktop\Worklife\Data\MLBootcamp\Project3\Part2\newtrain.csv")
test = pd.read_csv(r"C:\Users\ROG\Desktop\Worklife\Data\MLBootcamp\Project3\Part2\newtest.csv")

# %%
train.drop(columns=["Unnamed: 0"], inplace=True)
test.drop(columns=["Unnamed: 0"], inplace=True)

# %%
train
# Out:
#         overall  vote  verified  reviewTime      reviewerID        asin  \
# 0             2   0.0         0  2016-11-11   A2OSUEZJIN7BI  0511189877
# 1             5   0.0         1  2016-06-06  A2NETQRG6JHIG7  0511189877
# 2             4   0.0         1  2016-03-10  A12JHGROAX49G7  0511189877
# 3             5   0.0         1  2016-01-14  A1KV65E2TMMG6F  0511189877
# 4             5   0.0         1  2016-10-20  A280POPEWI0NSA  0594459451
# ...         ...   ...       ...         ...             ...         ...
# 838939        5   0.0         1  2017-07-25  A1OOVLE2KZ6KGA  B01HJCN1EI
# 838940        1   0.0         1  2017-04-04   A77K1B31UAQ29  B01HJCN1EI
# 838941        3   0.0         1  2017-07-08  A2SVXUVUAWUDK2  B01HJH42KU
# 838942        5   2.0         1  2016-12-01  A2HUZO7MQAY5I2  B01HJH40WU
# 838943        5   0.0         1  2017-03-31  A1FGCIRPRNZWD5  B01HJF704M
#
#              reviewerName                                         reviewText  \
# 0                   Chris  older remote thought upgrade twc stuck fails d...
# 1            Qrysta White  first ive ever remote needed programming whats...
# 2                 Linwood  worked company called feedback told send refun...
# 3           Dane Williams  tired remote wrong side bed going buy generic ...
# 4             Kristina H.  purchasing cheap cords another website little ...
# ...                   ...                                                ...
# 838939            Puddzee  favorite charging cords reasons length means r...
# 838940  addictedtoreading  updateafter months gentle cable twisted nearly...
# 838941             Andrew  okay connection becomes iffy uses especially e...
# 838942     michael clontz  ok odd happened clicked sales item cable recei...
# 838943             Brando  plugged usb extension gaming pc ideally placed...
#
#                                                   summary  text_length
# 0                                            Cannot Learn          561
# 1                     zero programming needed!  Miracle!?          450
# 2                           Works Good and programs easy.          205
# 3                                      Same as TWC remote          284
# 4                                       Good Quality Cord          247
# ...                                                   ...          ...
# 838939                                   Worth the price.          276
# 838940                  UPDATE...BREAKS AND SLOW CHARGING          228
# 838941  Hope this makes sense. You'd understand if you...          242
# 838942     Not the correct product as linked in the sale.          528
# 838943                                Works well enough..          432
#
# [838944 rows x 10 columns]

# %%
test
# Out:
#        vote  verified  reviewTime      reviewerID        asin  \
# 0       0.0         1  2018-06-04  A20GGWE66JW9X2  B006Z394GM
# 1       0.0         1  2018-02-18   ARYJWXHEYHG9M  B005BE058W
# 2       0.0         1  2018-01-20  A10LHZ7WFZ7HLL  B01DA0YCNC
# 3       0.0         1  2018-06-25  A11VN8EOHNLP72  B00FBJ4KYC
# 4       3.0         1  2016-08-17  A194Y8P8TVT7P9  B00P7G82TS
# ...     ...       ...         ...             ...         ...
# 19995   0.0         1  2016-08-18  A2938GNQGHT0BL  B01DACQMH4
# 19996   0.0         1  2018-04-09   ALL1OIDIGVJDH  B005HGM1D6
# 19997   0.0         1  2016-01-20  A17HGOTUOG2BFJ  B007FMG6D6
# 19998   3.0         1  2016-01-13  A1HC6MT5PMOIRN  B00KQCOV5C
# 19999   0.0         0  2016-04-24   AIFLY2HF8NS8U  B01A52KLTC
#
#           reviewerName                                         reviewText  \
# 0        Brian C Toner  name description misleading supposed conversio...
# 1                Snake  molex connectors power supply started melting ...
# 2      Amazon Customer  remote constantly disconnects roku player free...
# 3          Jeremy Bray  purchased year protection plan security system...
# 4                 Mark  regretted ever since gps receiver worked day h...
# ...                ...                                                ...
# 19995      Sarah White  ive running days far im pretty pleased upgrade...
# 19996         Amigaman  looking high quality audio interconnect cables...
# 19997    Luke Snedecor  perfect exactly told cable ittle short mean no...
# 19998  Richmond Mensah  dell latitude doubting computer support ram gr...
# 19999   Andre Lawrence  div classasection aspacingsmall aspacingtopmin...
#
#                                                  summary
# 0      The prize for most useless invention of all ti...
# 1                                 MELTED MOLEX CONNECTOR
# 2                                 Bricked on the regular
# 3                                          DO NOT BUY!!!
# 4                                  Nightmare - don't buy
# ...                                                  ...
# 19995  but so far I'm pretty pleased. I upgraded from...
# 19996                   High Quality Audio Interconnects
# 19997                                     Totally works!
# 19998                                Dell latitude E6330
# 19999  Zmodo Pivot Wireless Surveillance Camera: A Cr...
#
# [20000 rows x 8 columns]

# %% [markdown]
# In this problem, we just want to focus on the classic "Sentiment analysis using text data" problem, and thence we will use only two columns: reviewText, overall.

# %%
train = train[["reviewText", "overall"]]
test = test[["reviewText"]]

# %%
train
# Out:
#                                                reviewText  overall
# 0       older remote thought upgrade twc stuck fails d...        2
# 1       first ive ever remote needed programming whats...        5
# 2       worked company called feedback told send refun...        4
# 3       tired remote wrong side bed going buy generic ...        5
# 4       purchasing cheap cords another website little ...        5
# ...                                                   ...      ...
# 838939  favorite charging cords reasons length means r...        5
# 838940  updateafter months gentle cable twisted nearly...        1
# 838941  okay connection becomes iffy uses especially e...        3
# 838942  ok odd happened clicked sales item cable recei...        5
# 838943  plugged usb extension gaming pc ideally placed...        5
#
# [838944 rows x 2 columns]

# %%
test
# Out:
#                                               reviewText
# 0      name description misleading supposed conversio...
# 1      molex connectors power supply started melting ...
# 2      remote constantly disconnects roku player free...
# 3      purchased year protection plan security system...
# 4      regretted ever since gps receiver worked day h...
# ...                                                  ...
# 19995  ive running days far im pretty pleased upgrade...
# 19996  looking high quality audio interconnect cables...
# 19997  perfect exactly told cable ittle short mean no...
# 19998  dell latitude doubting computer support ram gr...
# 19999  div classasection aspacingsmall aspacingtopmin...
#
# [20000 rows x 1 columns]

# %% [markdown]
# We have already lowercased all of our data and implemented lemmatization and some other stuff, but just in case we will be doing some of that preprocessing again to make the model compatible to what we are pursuing.
#
# Before that we will need to handle imbalancement.
#
# Based on the train data size, we have decided not to oversample anything. Despite loosing some data, we will need less time adjusting our model and we can always go back to oversampling, but for now we will undersample all the classes to 50000 rows.

# %%
undersampler = RandomUnderSampler(sampling_strategy={1: 50000, 2: 50000, 3: 50000, 4: 50000, 5: 50000}, random_state=78)
X_resampled, y_resampled = undersampler.fit_resample(train.drop(columns=["overall"]), train['overall'])

# %%
balanced_distribution = y_resampled.value_counts().sort_index()
print("Balanced Rating Distribution:")
print(balanced_distribution)
# Out:
# Balanced Rating Distribution:
# overall
# 1    50000
# 2    50000
# 3    50000
# 4    50000
# 5    50000
# Name: count, dtype: int64

# %% [markdown]
# A lil bit of text processing after handling imbalancement:
